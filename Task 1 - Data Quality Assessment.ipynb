# %%
import pandas as pd

# %%
Transactions = pd.read_excel(r"C:\Users\Dell\KPMG_VI_New_raw_data_update_final.xlsx",sheet_name="Transactions",header=1)
NewCustomerList = pd.read_excel(r"C:\Users\Dell\KPMG_VI_New_raw_data_update_final.xlsx",sheet_name="NewCustomerList",header=1)
CustomerDemographic = pd.read_excel(r"C:\Users\Dell\KPMG_VI_New_raw_data_update_final.xlsx",sheet_name="CustomerDemographic",header=1)
CustomerAddress = pd.read_excel(r"C:\Users\Dell\KPMG_VI_New_raw_data_update_final.xlsx",sheet_name="CustomerAddress",header=1)
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_13676/997927209.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   NewCustomerList = pd.read_excel(r"C:\Users\Dell\KPMG_VI_New_raw_data_update_final.xlsx",sheet_name="NewCustomerList",header=1)
# C:\Users\Dell\AppData\Local\Temp/ipykernel_13676/997927209.py:3: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   CustomerDemographic = pd.read_excel(r"C:\Users\Dell\KPMG_VI_New_raw_data_update_final.xlsx",sheet_name="CustomerDemographic",header=1)

# %% [markdown]
# # TRANSACTIONS DATASET

# %% [markdown]
# ## 1. Explore & Check the Transactions Dataset

# %%
Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
##The product_first_sold_date is stored as float64, This column should be changed to data

# %%
Transactions['product_first_sold_date'] = pd.to_datetime(Transactions['product_first_sold_date'], unit='s')
Transactions['product_first_sold_date'].head(30)
# Out:
# 0    1970-01-01 11:27:25
# 1    1970-01-01 11:35:01
# 2    1970-01-01 10:06:01
# 3    1970-01-01 10:02:25
# 4    1970-01-01 11:43:46
# 5    1970-01-01 10:50:31
# 6    1970-01-01 09:29:25
# 7    1970-01-01 11:05:15
# 8    1970-01-01 09:17:35
# 9    1970-01-01 10:36:56
# 10   1970-01-01 11:19:44
# 11   1970-01-01 11:42:52
# 12   1970-01-01 09:35:27
# 13   1970-01-01 09:36:26
# 14   1970-01-01 10:36:33
# 15   1970-01-01 10:31:13
# 16   1970-01-01 10:36:46
# 17   1970-01-01 09:24:48
# 18   1970-01-01 11:05:15
# 19   1970-01-01 10:22:17
# 20   1970-01-01 10:05:34
# 21   1970-01-01 10:06:01
# 22   1970-01-01 11:42:25
# 23   1970-01-01 11:46:44
# 24   1970-01-01 09:27:59
# 25   1970-01-01 11:42:25
# 26   1970-01-01 11:24:07
# 27   1970-01-01 11:49:20
# 28   1970-01-01 11:51:50
# 29   1970-01-01 11:38:42
# Name: product_first_sold_date, dtype: datetime64[ns]

# %% [raw]
# The product_first_sold_date seems to be incorrect. It shows same date & just different times. We need to understand the source of the data and how it was collected.

# %% [markdown]
# ## 2. Identify Missing Values in the Transactions Dataset

# %%
Transactions.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %% [raw]
# We may or may not drop the null values depending on the insights we are looking for.

# %%
Transactions.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3. Explore Columns

# %%
Transactions.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
Transactions['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
Transactions['online_order'].value_counts()
# Out:
# 1.0    9829
# 0.0    9811
# Name: online_order, dtype: int64

# %%
Transactions['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
Transactions['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
Transactions['product_class'].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
Transactions['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %% [markdown]
# # NEW CUSTOMER LIST DATASET

# %% [markdown]
# ## 1. Explore & Check the new customer list dataset

# %%
NewCustomerList.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
NewCustomerList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %% [markdown]
# 5 columns are unnamed. Either we need to get information regarding what they are or drop them.

# %%
# Drop Unnamed Column
unnamed_cols = ['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20']
NewCustomerList = NewCustomerList.drop(unnamed_cols, axis=1)

# %% [markdown]
# ## 2. Identifying Missing Values in the New Customer List dataset

# %%
NewCustomerList.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
NewCustomerList.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3. Explore Columns

# %%
NewCustomerList['wealth_segment'].value_counts()
# Out:
# Mass Customer        508
# High Net Worth       251
# Affluent Customer    241
# Name: wealth_segment, dtype: int64

# %%
NewCustomerList['owns_car'].value_counts()
# Out:
# No     507
# Yes    493
# Name: owns_car, dtype: int64

# %%
NewCustomerList['job_industry_category'].value_counts()
# Out:
# Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %%
NewCustomerList['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
NewCustomerList['gender'].str.replace('U','Unspecified')
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 995      Male
# 996      Male
# 997    Female
# 998      Male
# 999      Male
# Name: gender, Length: 1000, dtype: object

# %% [markdown]
# # Customer Demographic Dataset

# %% [markdown]
# ## Explore & Check the Customer Demographic Data

# %%
CustomerDemographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
CustomerDemographic = CustomerDemographic.drop('default',axis=1)

# %%
CustomerDemographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  owns_car                             4000 non-null   object
# ...

# %% [markdown]
# ## 2. Identify Missing Values

# %%
CustomerDemographic.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
CustomerDemographic['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# F            1
# Femal        1
# M            1
# Name: gender, dtype: int64

# %%
CustomerDemographic['gender'] = CustomerDemographic['gender'].replace('F','Female').replace('M','Male').replace('Femal','Female').replace('U','Unspecified')

# %%
CustomerDemographic['gender'].value_counts()
# Out:
# Female         2039
# Male           1873
# Unspecified      88
# Name: gender, dtype: int64

# %% [markdown]
# ## Customer Address Dataset

# %%
CustomerAddress.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %% [markdown]
# # Join the Customer Demographic & New Customer Address

# %%
CustomerDemographic = pd.merge(CustomerDemographic, CustomerAddress, how='left', on='customer_id')

# %%
CustomerDemographic
# Out:
#       customer_id      first_name  last_name       gender  \
# 0               1         Laraine  Medendorp       Female
# 1               2             Eli    Bockman         Male
# 2               3           Arlin     Dearle         Male
# 3               4          Talbot        NaN         Male
# 4               5  Sheila-kathryn     Calton       Female
# ...           ...             ...        ...          ...
# 3995         3996         Rosalia   Halgarth       Female
# 3996         3997          Blanch     Nisuis       Female
# 3997         3998          Sarene    Woolley  Unspecified
# 3998         3999       Patrizius        NaN         Male
# 3999         4000           Kippy    Oldland         Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# ...

# %% [markdown]
# ## Add Customer ID 4000 onwards to the New Customer List

# %%
NewCustomerList
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
NewCustomerList.insert(0, 'customer_id', range(4001, 4001 + len(NewCustomerList)))

# %%
NewCustomerList.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0         4001    Chickie    Brister    Male
# 1         4002      Morly     Genery    Male
# 2         4003    Ardelis  Forrester  Female
# 3         4004     Lucine      Stutt  Female
# 4         4005    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases        DOB                   job_title  \
# 0                                   86 1957-07-12             General Manager
# 1                                   69 1970-03-22         Structural Engineer
# 2                                   10 1974-08-28      Senior Cost Accountant
# 3                                   64 1979-01-28  Account Representative III
# 4                                   34 1965-09-21           Financial Analyst
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0         Manufacturing      Mass Customer                  N      Yes
# 1              Property      Mass Customer                  N       No
# ...

# %% [markdown]
# ## Combine Customer Demographic  and New Customer List

# %%
Df = pd.concat([CustomerDemographic, NewCustomerList], ignore_index=True, sort=False)

# %%
Df
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 4995         4996       Ferdinand  Romanetti    Male
# 4996         4997            Burk    Wortley    Male
# 4997         4998        Melloney      Temby  Female
# 4998         4999          Dickie    Cubbini    Male
# 4999         5000           Sylas    Duffill    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 3                                      33 1961-10-03
# 4                                      56 1977-05-13
# ...
